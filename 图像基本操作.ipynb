# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
import cv2#opencv读取的格式是BGR
import matplotlib.pyplot as plt
import numpy as np

image=cv2.imread('queen.jpg')

# %%
image
# Out:
# array([[[  2,   2,   2],
#         [  2,   2,   2],
#         [  2,   2,   2],
#         ...,
#         [ 20,  20,   6],
#         [ 19,  19,   5],
#         [ 27,  27,  13]],
#
#        [[  2,   2,   2],
#         [  2,   2,   2],
#         [  2,   2,   2],
#         ...,
#         [ 15,  15,   9],
#         [ 11,  11,   5],
#         [  6,   7,   0]],
#
#        [[  2,   2,   2],
#         [  2,   2,   2],
#         [  2,   2,   2],
#         ...,
#         [  6,   6,   6],
#         [  4,   4,   4],
#         [  7,   7,   7]],
#
#        ...,
#
#        [[196, 209, 217],
#         [198, 211, 219],
#         [201, 214, 222],
#         ...,
#         [240, 239, 241],
#         [236, 235, 237],
#         [239, 238, 240]],
#
#        [[196, 209, 217],
#         [198, 211, 219],
#         [200, 213, 221],
#         ...,
#         [244, 243, 245],
#         [238, 237, 239],
#         [239, 238, 240]],
#
#        [[198, 210, 216],
#         [199, 211, 217],
#         [197, 211, 217],
#         ...,
#         [236, 238, 238],
#         [233, 235, 235],
#         [237, 239, 239]]], dtype=uint8)

# %%
def cv_show(name,image):
    cv2.imshow(name,image)
    cv2.waitKey(0)
    cv2.destoryAllWindows()

# %%
image.shape
# Out:
# (849, 1200, 3)

# %%
import cv2
image=cv2.imread('queen.jpg',cv2.IMREAD_GRAYSCALE)#灰度图像，
image
# Out:
# array([[  2,   2,   2, ...,  16,  15,  23],
#        [  2,   2,   2, ...,  13,   9,   4],
#        [  2,   2,   2, ...,   6,   4,   7],
#        ...,
#        [210, 212, 215, ..., 240, 236, 239],
#        [210, 212, 214, ..., 244, 238, 239],
#        [210, 211, 211, ..., 238, 235, 239]], dtype=uint8)

# %%
image.shape
# Out:
# (849, 1200)

# %%
cv2.imshow('image',image)
cv2.waitKey(0)
cv2.destoryAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-bc9223347437> in <module>
#       1 cv2.imshow('image',image)
#       2 cv2.waitKey(0)
# ----> 3 cv2.destoryAllWindows()
#
# AttributeError: module 'cv2.cv2' has no attribute 'destoryAllWindows'

# %%
#保存 
cv2.imwrite('huiman.jpg',image)
# Out:
# True

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.size
# Out:
# 1018800

# %%
image.dtype
# Out:
# dtype('uint8')

# %%
vc = cv2.VideoCapture('scenery.MP4')

# %%
vc = cv2.VideoCapture('scenery.MP4')
#检查是否可以正常打开
if vc.isOpened():
    open,frame=vc.read()
else:
    open = False

# %%
import cv2
vc = cv2.VideoCapture('scenery.MP4')
#检查是否可以正常打开
if vc.isOpened():
    open,frame=vc.read()
else:
    open = False
while open:
    ret,frame = vc.read()
    if frame is None:
        break
    if ret == True:
        gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)#将彩色视频转化为灰色视频
        cv2.imshow('result',gray)
        if cv2.waitKey(10)&0xFF==27:#括号中数字越大，视频播放速度越慢。0xFF==27表示按ESC后退出视频播放
          break
vc.release()
cv2.destoryAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-13a32f517925> in <module>
#      16           break
#      17 vc.release()
# ---> 18 cv2.destoryAllWindows()
#
# AttributeError: module 'cv2.cv2' has no attribute 'destoryAllWindows'

# %%
#截取部分图像数据
import cv2

def cv_show(name,image):
    cv2.imshow(name,image)
    cv2.waitKey(0)
    cv2.destoryAllWindows()
    
image = cv2.imread('queen.jpg')
man = image[200:630,250:450]
cv_show('man',man)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-798211215792> in <module>
#       8 image = cv2.imread('man.jpg')
#       9 man = image[200:630,250:450]
# ---> 10 cv_show('man',man)
#
# <ipython-input-7-798211215792> in cv_show(name, image)
#       4     cv2.imshow(name,image)
#       5     cv2.waitKey(0)
# ----> 6     cv2.destoryAllWindows()
#       7
#       8 image = cv2.imread('man.jpg')
#
# AttributeError: module 'cv2.cv2' has no attribute 'destoryAllWindows'

# %% [markdown]
# 颜色通道提取

# %%
import cv2
image = cv2.imread('queen.jpg')
b,g,r=cv2.split(image)

# %%
b
# Out:
# array([[  2,   2,   2, ...,  20,  19,  27],
#        [  2,   2,   2, ...,  15,  11,   6],
#        [  2,   2,   2, ...,   6,   4,   7],
#        ...,
#        [196, 198, 201, ..., 240, 236, 239],
#        [196, 198, 200, ..., 244, 238, 239],
#        [198, 199, 197, ..., 236, 233, 237]], dtype=uint8)

# %%
b.shape
# Out:
# (849, 1200)

# %%
import cv2
import numpy as np
image = cv2.imread('queen.jpg')
(B,G,R) = cv2.split(image)
image = cv2.merge([B,G,R])
cv2.imshow('image',image)
cv2.imshow("Red",R)
cv2.imshow("Green",G)
cv2.imshow("Blue",B)
cv2.waitKey(0)
# Out:
# -1

# %%
#只保留R
def cv_show(name,image):
    cv2.imshow(name,image)
    cv2.waitKey(0)
    cv2.destoryAllWindows()
    
cur_img = image.copy()
cur_img[:,:,0] = 0
cur_img[:,:,1] = 0
cv_show('R',cur_img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-9f1709b54523> in <module>
#       8 cur_img[:,:,0] = 0
#       9 cur_img[:,:,1] = 0
# ---> 10 cv_show('G',cur_img)
#
# <ipython-input-9-9f1709b54523> in cv_show(name, image)
#       3     cv2.imshow(name,image)
#       4     cv2.waitKey(0)
# ----> 5     cv2.destoryAllWindows()
#       6
#       7 cur_img = image.copy()
#
# AttributeError: module 'cv2.cv2' has no attribute 'destoryAllWindows'

# %%
#只保留G
def cv_show(name,image):
    cv2.imshow(name,image)
    cv2.waitKey(0)
    cv2.destoryAllWindows()
    
cur_img = image.copy()
cur_img[:,:,0] = 0
cur_img[:,:,2] = 0
cv_show('G',cur_img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-246c5327e54a> in <module>
#       8 cur_img[:,:,0] = 0
#       9 cur_img[:,:,2] = 0
# ---> 10 cv_show('G',cur_img)
#
# <ipython-input-11-246c5327e54a> in cv_show(name, image)
#       3     cv2.imshow(name,image)
#       4     cv2.waitKey(0)
# ----> 5     cv2.destoryAllWindows()
#       6
#       7 cur_img = image.copy()
#
# AttributeError: module 'cv2.cv2' has no attribute 'destoryAllWindows'

# %%
#只保留B
def cv_show(name,image):
    cv2.imshow(name,image)
    cv2.waitKey(0)
    cv2.destoryAllWindows()
    
cur_img = image.copy()
cur_img[:,:,2] = 0
cur_img[:,:,1] = 0
cv_show('B',cur_img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-5781b1eb2641> in <module>
#       8 cur_img[:,:,2] = 0
#       9 cur_img[:,:,1] = 0
# ---> 10 cv_show('B',cur_img)
#
# <ipython-input-3-5781b1eb2641> in cv_show(name, image)
#       3     cv2.imshow(name,image)
#       4     cv2.waitKey(0)
# ----> 5     cv2.destoryAllWindows()
#       6
#       7 cur_img = image.copy()
#
# AttributeError: module 'cv2.cv2' has no attribute 'destoryAllWindows'

# %% [markdown]
# cv2.BORDER_REPLICATE复制法，复制最边缘像素
# cv2.BORDER_REFLECT反射法，对感兴趣的图像中的像素在两边进行入职
# cv2.BORDER_REFLECT101反射法，以最边缘像素为轴，对称 cv2.BORDER_WRAP外包装法
# cv2.BORDER_CONSTANT常良法

# %%
import cv2
import numpy as np
img=cv2.imread('man.jpg')
top_size,bottom_size,left_size,right_size=(150,150,150,150)
replicate=cv2.copyMakeBorder(img,top_size,bottom_size,left_size,right_size,borderType=cv2.BORDER_REPLICATE)
reflect=cv2.copyMakeBorder(img,top_size,bottom_size,left_size,right_size,borderType=cv2.BORDER_REFLECT)
reflect101=cv2.copyMakeBorder(img,top_size,bottom_size,left_size,right_size,borderType=cv2.BORDER_REFLECT101)
wrap=cv2.copyMakeBorder(img,top_size,bottom_size,left_size,right_size,borderType=cv2.BORDER_WRAP)
constant=cv2.copyMakeBorder(img,top_size,bottom_size,left_size,right_size,borderType=cv2.BORDER_CONSTANT,value=0)

# %%
import matplotlib.pyplot as plt
plt.subplot(231),plt.imshow(img,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANTL')

plt.show()

# cv2.BORDER_REPLICATE复制法，复制最边缘像素
# cv2.BORDER_REFLECT反射法，对感兴趣的图像中的像素在两边进行入职
# cv2.BORDER_REFLECT101反射法，以最边缘像素为轴，对称 cv2.BORDER_WRAP外包装法
# cv2.BORDER_CONSTANT常良法

# %% [markdown]
# 数值计算

# %%
img_queen = cv2.imread('queen.jpg')
img_man = cv2.imread('man.jpg')

# %%
img_man2 =img_man + 10 #在图像中每个像素点+10，
img_man[:5,:,0]
# Out:
# array([[ 2,  2,  2, ..., 20, 19, 27],
#        [ 2,  2,  2, ..., 15, 11,  6],
#        [ 2,  2,  2, ...,  6,  4,  7],
#        [ 2,  2,  2, ...,  5,  0,  2],
#        [ 2,  2,  2, ...,  5,  0,  3]], dtype=uint8)

# %%
img_man2[:5,:,0]
# Out:
# array([[12, 12, 12, ..., 30, 29, 37],
#        [12, 12, 12, ..., 25, 21, 16],
#        [12, 12, 12, ..., 16, 14, 17],
#        [12, 12, 12, ..., 15, 10, 12],
#        [12, 12, 12, ..., 15, 10, 13]], dtype=uint8)

# %%
#相当于%256           
(img_man + img_man2)[:5,:,0]
# Out:
# array([[14, 14, 14, ..., 50, 48, 64],
#        [14, 14, 14, ..., 40, 32, 22],
#        [14, 14, 14, ..., 22, 18, 24],
#        [14, 14, 14, ..., 20, 10, 14],
#        [14, 14, 14, ..., 20, 10, 16]], dtype=uint8)

# %%
cv2.add(img_man,img_man2)[:5,:,0]
# Out:
# array([[14, 14, 14, ..., 50, 48, 64],
#        [14, 14, 14, ..., 40, 32, 22],
#        [14, 14, 14, ..., 22, 18, 24],
#        [14, 14, 14, ..., 20, 10, 14],
#        [14, 14, 14, ..., 20, 10, 16]], dtype=uint8)

# %%
img_man +img_queen
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-f5dacd97a133> in <module>
# ----> 1 img_man +img_queen
#
# ValueError: operands could not be broadcast together with shapes (849,1200,3) (640,640,3)

# %%
img_man.shape
# Out:
# (640, 640, 3)

# %%
img_queen.shape
# Out:
# (640, 640, 3)

# %%
img_man=cv2.resize(img_man,(640,640))
img_man.shape
# Out:
# (640, 640, 3)

# %%
res = cv2.resize(img,(0,0),fx=3,fy=1)
plt.imshow(res)

# %%
res = cv2.resize(img,(0,0),fx=1,fy=3)
plt.imshow(res)

# %%
res = cv2.resize(img,(0,0),fx=5,fy=5)
plt.imshow(res)

# %%
res =cv2.addWeighted(img_man,0.7,img_queen,0.3,0.5)
plt.imshow(res)
